# %%
import numpy as np
from qiskit import *
# %matplotlib inline
shots = 4096

# %% [markdown]
# # problem Deutcha
# Zdefiniowane są 4 funkcje, spośród nich dwie są stałe, a dwie zmienne.
#
# Mamy jedną z tych funkcji. Ile razy musimy ją uruchomić, aby sprawdzić czy jest ona stała czy zmienna?

# %% [markdown]
# bramka Uf0 (stała) pomiędzy bramkami Hadamarda:

# %%
circ = QuantumCircuit(2,1)
circ.x(1)
circ.barrier()
circ.h(0)
circ.h(1)
circ.barrier()
circ.iden(0)
circ.barrier()
circ.h(0)
circ.h(1)
circ.barrier()
circ.measure(0,0)
circ.draw()

# %% [markdown]
# Jeśli na wyjściu otrzymamy 1 to funkcja jest zmienna, jesli 0 to funkcja jest stała.

# %%
backend_sim = Aer.get_backend('qasm_simulator')
job_sim = execute(circ, backend_sim, shots=shots)
result_sim = job_sim.result()
counts = result_sim.get_counts(circ)

from qiskit import IBMQ
IBMQ.load_account()
provider = IBMQ.get_provider(group='open')
# provider.backends()

backend = provider.get_backend('ibmq_london')

from qiskit.tools.monitor import job_monitor

job_exp = execute(circ, backend=backend, shots=shots)
job_monitor(job_exp)

result_exp = job_exp.result()
counts_exp = result_exp.get_counts(circ)
from qiskit.visualization import plot_histogram
plot_histogram([counts_exp,counts], legend=['Device', 'Simulator'])
# Out:
# Job Status: job has successfully run

# %% [markdown]
# bramka Uf1 (zmienna) pomiędzy bramkami Hadamarda:

# %%
circ = QuantumCircuit(2,1)
circ.x(1)
circ.barrier()
circ.h(0)
circ.h(1)
circ.barrier()
circ.cx(0,1)
circ.barrier()
circ.h(0)
circ.h(1)
circ.barrier()
circ.measure(0,0)
circ.draw()

# %% [markdown]
# Jeśli na wyjściu otrzymamy 1 to funkcja jest zmienna, jesli 0 to funkcja jest stała.

# %%
backend_sim = Aer.get_backend('qasm_simulator')
job_sim = execute(circ, backend_sim, shots=shots)
result_sim = job_sim.result()
counts = result_sim.get_counts(circ)

from qiskit import IBMQ
IBMQ.load_account()
provider = IBMQ.get_provider(group='open')
# provider.backends()

backend = provider.get_backend('ibmq_london')

from qiskit.tools.monitor import job_monitor

job_exp = execute(circ, backend=backend, shots=shots)
job_monitor(job_exp)

result_exp = job_exp.result()
counts_exp = result_exp.get_counts(circ)
from qiskit.visualization import plot_histogram
plot_histogram([counts_exp,counts], legend=['Device', 'Simulator'])
# Out:
# Credentials are already in use. The existing account in the session will be replaced.
# Job Status: job has successfully run

# %% [markdown]
# bramka Uf2 (zmienna) pomiędzy bramkami Hadamarda:

# %%
circ = QuantumCircuit(2,1)
circ.x(1)
circ.barrier()
circ.h(0)
circ.h(1)
circ.barrier()
circ.x(1)
circ.cx(0,1)
circ.barrier()
circ.h(0)
circ.h(1)
circ.measure(0,0)
circ.draw()

# %% [markdown]
# Jeśli na wyjściu otrzymamy 1 to funkcja jest zmienna, jesli 0 to funkcja jest stała.

# %%
backend_sim = Aer.get_backend('qasm_simulator')
job_sim = execute(circ, backend_sim, shots=shots)
result_sim = job_sim.result()
counts = result_sim.get_counts(circ)

from qiskit import IBMQ
IBMQ.load_account()
provider = IBMQ.get_provider(group='open')
# provider.backends()

backend = provider.get_backend('ibmq_london')

from qiskit.tools.monitor import job_monitor

job_exp = execute(circ, backend=backend, shots=shots)
job_monitor(job_exp)

result_exp = job_exp.result()
counts_exp = result_exp.get_counts(circ)
from qiskit.visualization import plot_histogram
plot_histogram([counts_exp,counts], legend=['Device', 'Simulator'])
# Out:
# Credentials are already in use. The existing account in the session will be replaced.
# Job Status: job has successfully run

# %% [markdown]
# bramka Uf3 (stała) pomiędzy bramkami Hadamarda:

# %%
circ = QuantumCircuit(2,1)
circ.x(1)
circ.barrier()
circ.h(0)
circ.h(1)
circ.barrier()
circ.x(1)
circ.barrier()
circ.h(0)
circ.h(1)
circ.measure(0,0)
circ.draw()

# %% [markdown]
# Jeśli na wyjściu otrzymamy 1 to funkcja jest zmienna, jesli 0 to funkcja jest stała.

# %%
backend_sim = Aer.get_backend('qasm_simulator')
job_sim = execute(circ, backend_sim, shots=shots)
result_sim = job_sim.result()
counts = result_sim.get_counts(circ)

from qiskit import IBMQ
IBMQ.load_account()
provider = IBMQ.get_provider(group='open')
# provider.backends()

backend = provider.get_backend('ibmq_london')

from qiskit.tools.monitor import job_monitor

job_exp = execute(circ, backend=backend, shots=shots)
job_monitor(job_exp)

result_exp = job_exp.result()
counts_exp = result_exp.get_counts(circ)
from qiskit.visualization import plot_histogram
plot_histogram([counts_exp,counts], legend=['Device', 'Simulator'])
# Out:
# Credentials are already in use. The existing account in the session will be replaced.
# Job Status: job has successfully run
